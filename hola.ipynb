# %%
import pandas as pd
import re

# %%
data = pd.read_csv("data.csv")


data.head()
# Out:
#    Unnamed: 0                                         lastfm_url  \
# 0           0  https://www.last.fm/music/eminem/_/%2527till%2...
# 1           1  https://www.last.fm/music/metallica/_/st.%2banger
# 2           2  https://www.last.fm/music/rick%2bross/_/speedi...
# 3           3  https://www.last.fm/music/m.i.a./_/bamboo%2bbanga
# 4           4    https://www.last.fm/music/dope/_/die%2bmf%2bdie
#
#               track     artist                                       seeds  \
# 0  'Till I Collapse     Eminem                              ['aggressive']
# 1         St. Anger  Metallica                              ['aggressive']
# 2          Speedin'  Rick Ross                              ['aggressive']
# 3      Bamboo Banga     M.I.A.  ['aggressive', 'fun', 'sexy', 'energetic']
# 4        Die MF Die       Dope                              ['aggressive']
#
#    number_of_emotion_tags  valence_tags  arousal_tags  dominance_tags  \
# ...

# %%
def normalize_text(text):
    # Convertir a minúsculas
    text = text.lower()
    # Eliminar caracteres no alfabéticos (mantener espacios)
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text


data[data['track'].apply(lambda x: normalize_text(x)).str.contains(normalize_text("Till I Collapse"))]
# Out:
#    Unnamed: 0                                         lastfm_url  \
# 0           0  https://www.last.fm/music/eminem/_/%2527till%2...
#
#               track  artist           seeds  number_of_emotion_tags  \
# 0  'Till I Collapse  Eminem  ['aggressive']                       6
#
#    valence_tags  arousal_tags  dominance_tags  \
# 0          4.55      5.273125        5.690625
#
#                                    mbid              spotify_id genre  \
# 0  cab93def-26c5-4fb0-bedd-26ec4c1619e1  4xkOaSrkexMciUUogZKVTS   rap
#
#    uploaded
# 0     False
