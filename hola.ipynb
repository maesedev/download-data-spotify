# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

data = data.loc[10000:20000]

data.head()
# Out:
#        Unnamed: 0                                         lastfm_url  \
# 10000       10000  https://www.last.fm/music/animal%2bcollective/...
# 10001       10001  https://www.last.fm/music/jonny%2bgreenwood/_/...
# 10002       10002  https://www.last.fm/music/queens%2bof%2bthe%2b...
# 10003       10003      https://www.last.fm/music/bauhaus/_/ear%2bwax
# 10004       10004  https://www.last.fm/music/midtown/_/god%2bis%2...
#
#                                       track                   artist  \
# 10000                       The Living Toys        Animal Collective
# 10001                     Stranded The Line          Jonny Greenwood
# 10002  The Fun Machine Took A Shit And Died  Queens of the Stone Age
# 10003                               Ear Wax                  Bauhaus
# 10004                           God Is Dead                  Midtown
#
#                      seeds  number_of_emotion_tags  valence_tags  \
# 10000            ['eerie']                       1      3.400000
# ...

# %%
data = data.loc[10000:40000]
data.tail()
# Out:
#        Unnamed: 0                                         lastfm_url  \
# 19996       19996  https://www.last.fm/music/grimes/_/sagrad%2b%2...
# 19997       19997  https://www.last.fm/music/cocteau%2btwins/_/do...
# 19998       19998  https://www.last.fm/music/burial/_/come%2bdown...
# 19999       19999  https://www.last.fm/music/the%2bbreeders/_/off...
# 20000       20000  https://www.last.fm/music/brazilian%2bgirls/_/...
#
#                    track           artist                           seeds  \
# 19996  Sagrad прекрасный           Grimes          ['dreamy', 'ethereal']
# 19997             Donimo    Cocteau Twins          ['dreamy', 'ethereal']
# 19998    Come Down to Us           Burial                      ['dreamy']
# 19999            Off You     The Breeders  ['dreamy', 'gentle', 'quirky']
# 20000         Lazy Lover  Brazilian Girls                      ['dreamy']
#
#        number_of_emotion_tags  valence_tags  arousal_tags  dominance_tags  \
# ...
